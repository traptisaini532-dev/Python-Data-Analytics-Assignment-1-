# %%
import pandas as pd

# %% [markdown]
# # Load a dataset

# %%
df=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Data Anayltic\Pandas\1000_employeesz.csv")

# %%
df
# Out:
#      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 0       1  Pooja Sharma            Manager  Marketing   32         671897
# 1       2   Arjun Saini       HR Executive         IT   59        1387572
# 2       3  Priya Sharma       HR Executive      Sales   45         511251
# 3       4  Vikas Sharma         Accountant    Finance   54         325244
# 4       5   Sneha Kumar    Sales Executive         IT   50         403448
# ..    ...           ...                ...        ...  ...            ...
# 995   996   Rohan Joshi            Manager      Sales   33        1292140
# 996   997  Anjali Joshi         Accountant         IT   35         606056
# 997   998   Arjun Mehta    Sales Executive         HR   56        1079105
# 998   999   Neha Sharma            Manager         HR   55        1276940
# 999  1000   Sneha Kumar  Software Engineer         HR   23         462474
#
#       Hire_Date    Country
# 0    2016-10-14         UK
# ...

# %%
df.head()
# Out:
#    EEID     Full_Name        Job_Title Department  Age  Annual_Salary  \
# 0     1  Pooja Sharma          Manager  Marketing   32         671897
# 1     2   Arjun Saini     HR Executive         IT   59        1387572
# 2     3  Priya Sharma     HR Executive      Sales   45         511251
# 3     4  Vikas Sharma       Accountant    Finance   54         325244
# 4     5   Sneha Kumar  Sales Executive         IT   50         403448
#
#     Hire_Date Country
# 0  2016-10-14      UK
# 1  2020-04-23     USA
# 2  2020-02-02     USA
# 3  2019-03-23     USA
# 4  2022-05-20  Canada

# %% [markdown]
# # Basic Dataset Information

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['EEID', 'Full_Name', 'Job_Title', 'Department', 'Age', 'Annual_Salary',
#        'Hire_Date', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   int64
#  1   Full_Name      1000 non-null   object
#  2   Job_Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Age            1000 non-null   int64
#  5   Annual_Salary  1000 non-null   int64
#  6   Hire_Date      1000 non-null   object
#  7   Country        1000 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 0       1  Pooja Sharma            Manager  Marketing   32         671897
# 1       2   Arjun Saini       HR Executive         IT   59        1387572
# 2       3  Priya Sharma       HR Executive      Sales   45         511251
# 3       4  Vikas Sharma         Accountant    Finance   54         325244
# 4       5   Sneha Kumar    Sales Executive         IT   50         403448
# ..    ...           ...                ...        ...  ...            ...
# 995   996   Rohan Joshi            Manager      Sales   33        1292140
# 996   997  Anjali Joshi         Accountant         IT   35         606056
# 997   998   Arjun Mehta    Sales Executive         HR   56        1079105
# 998   999   Neha Sharma            Manager         HR   55        1276940
# 999  1000   Sneha Kumar  Software Engineer         HR   23         462474
#
#       Hire_Date    Country
# ...

# %%
df['Annual_Salary'].unique()
# Out:
# array([ 671897, 1387572,  511251,  325244,  403448, 1071294,  543246,
#         738777,  335912, 1461638, 1130523, 1040531, 1270655,  604610,
#         701706,  718917,  630274,  420500, 1441546,  864601, 1094312,
#        1366406, 1476598,  678804,  308331, 1345099,  566012, 1293463,
#         592072,  546503,  505337, 1250834,  430071,  528282,  619449,
#        1228252, 1044474, 1013262,  384214,  366663, 1233691, 1246819,
#         865356,  426936,  734991,  907626,  439298,  897903,  878013,
#         414923, 1321779,  742150,  786895,  692487, 1255171, 1477001,
#         799976,  914805, 1463100,  956625,  302782,  629244,  584540,
#        1109613, 1339701, 1133293,  437789,  563655, 1385430, 1494772,
#        1168718, 1184356, 1299185, 1335572, 1051521, 1048916, 1089695,
#        1487219,  577195,  318773,  455076,  677486,  489242,  747925,
#        1098732,  908559,  983204,  955122,  447021, 1345799,  301148,
# ...

# %%
df['Country'].nunique()
# Out:
# 5

# %%
df.describe()
# Out:
#               EEID          Age  Annual_Salary
# count  1000.000000  1000.000000   1.000000e+03
# mean    500.500000    40.026000   8.808740e+05
# std     288.819436    11.703431   3.494568e+05
# min       1.000000    21.000000   3.001120e+05
# 25%     250.750000    30.000000   5.672080e+05
# 50%     500.500000    39.000000   8.853620e+05
# 75%     750.250000    51.000000   1.184825e+06
# max    1000.000000    60.000000   1.498893e+06

# %% [markdown]
# # Data Cleaning

# %%
# Check missing values
df.isnull().sum()
# Out:
# EEID             0
# Full_Name        0
# Job_Title        0
# Department       0
# Age              0
# Annual_Salary    0
# Hire_Date        0
# Country          0
# dtype: int64

# %%
# Fill the missing age with median
df1=df['Age'].fillna(df['Age'].median())

# %%
df1
# Out:
# 0      32
# 1      59
# 2      45
# 3      54
# 4      50
#        ..
# 995    33
# 996    35
# 997    56
# 998    55
# 999    23
# Name: Age, Length: 1000, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df2=df.drop_duplicates()

# %%
df2
# Out:
#      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 0       1  Pooja Sharma            Manager  Marketing   32         671897
# 1       2   Arjun Saini       HR Executive         IT   59        1387572
# 2       3  Priya Sharma       HR Executive      Sales   45         511251
# 3       4  Vikas Sharma         Accountant    Finance   54         325244
# 4       5   Sneha Kumar    Sales Executive         IT   50         403448
# ..    ...           ...                ...        ...  ...            ...
# 995   996   Rohan Joshi            Manager      Sales   33        1292140
# 996   997  Anjali Joshi         Accountant         IT   35         606056
# 997   998   Arjun Mehta    Sales Executive         HR   56        1079105
# 998   999   Neha Sharma            Manager         HR   55        1276940
# 999  1000   Sneha Kumar  Software Engineer         HR   23         462474
#
#       Hire_Date    Country
# 0    2016-10-14         UK
# ...

# %% [markdown]
# # Data Filtering

# %%
df[df['Age']>40]
# Out:
#      EEID     Full_Name        Job_Title Department  Age  Annual_Salary  \
# 1       2   Arjun Saini     HR Executive         IT   59        1387572
# 2       3  Priya Sharma     HR Executive      Sales   45         511251
# 3       4  Vikas Sharma       Accountant    Finance   54         325244
# 4       5   Sneha Kumar  Sales Executive         IT   50         403448
# 6       7   Sneha Patel          Manager      Sales   47         543246
# ..    ...           ...              ...        ...  ...            ...
# 992   993  Sneha Sharma     Data Analyst    Finance   51        1062191
# 993   994   Sneha Singh          Manager    Finance   45        1168046
# 994   995   Arjun Gupta     HR Executive         IT   55        1258150
# 997   998   Arjun Mehta  Sales Executive         HR   56        1079105
# 998   999   Neha Sharma          Manager         HR   55        1276940
#
#       Hire_Date    Country
# 1    2020-04-23        USA
# 2    2020-02-02        USA
# ...

# %%
df[df['Country']== 'India']
# Out:
#      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 13     14  Anjali Yadav  Software Engineer         IT   60         604610
# 16     17   Rahul Singh  Software Engineer    Finance   21         630274
# 24     25  Pooja Sharma    Sales Executive      Sales   41         308331
# 29     30   Priya Saini       Data Analyst  Marketing   32         546503
# 31     32   Vikas Saini       HR Executive    Finance   49        1250834
# ..    ...           ...                ...        ...  ...            ...
# 974   975    Neha Verma         Accountant         HR   47        1180977
# 975   976   Arjun Saini  Software Engineer         HR   36         677466
# 977   978   Amit Sharma         Accountant         HR   34        1003781
# 989   990  Anjali Mehta       Data Analyst         IT   50         673884
# 996   997  Anjali Joshi         Accountant         IT   35         606056
#
#       Hire_Date Country
# 13   2023-04-30   India
# 16   2023-06-30   India
# ...

# %%
df[df['Department']== 'IT']
# Out:
#      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 1       2   Arjun Saini       HR Executive         IT   59        1387572
# 4       5   Sneha Kumar    Sales Executive         IT   50         403448
# 8       9   Sneha Joshi    Sales Executive         IT   57         335912
# 12     13    Neha Mehta  Software Engineer         IT   43        1270655
# 13     14  Anjali Yadav  Software Engineer         IT   60         604610
# ..    ...           ...                ...        ...  ...            ...
# 989   990  Anjali Mehta       Data Analyst         IT   50         673884
# 990   991  Anjali Mehta       Data Analyst         IT   59         860326
# 991   992   Pooja Patel            Manager         IT   46         432844
# 994   995   Arjun Gupta       HR Executive         IT   55        1258150
# 996   997  Anjali Joshi         Accountant         IT   35         606056
#
#       Hire_Date Country
# 1    2020-04-23     USA
# 4    2022-05-20  Canada
# ...

# %%
df[(df['Age'] > 25) & (df['Department'] == 'IT')]
# Out:
#      EEID     Full_Name          Job_Title Department  Age  Annual_Salary  \
# 1       2   Arjun Saini       HR Executive         IT   59        1387572
# 4       5   Sneha Kumar    Sales Executive         IT   50         403448
# 8       9   Sneha Joshi    Sales Executive         IT   57         335912
# 12     13    Neha Mehta  Software Engineer         IT   43        1270655
# 13     14  Anjali Yadav  Software Engineer         IT   60         604610
# ..    ...           ...                ...        ...  ...            ...
# 989   990  Anjali Mehta       Data Analyst         IT   50         673884
# 990   991  Anjali Mehta       Data Analyst         IT   59         860326
# 991   992   Pooja Patel            Manager         IT   46         432844
# 994   995   Arjun Gupta       HR Executive         IT   55        1258150
# 996   997  Anjali Joshi         Accountant         IT   35         606056
#
#       Hire_Date Country
# 1    2020-04-23     USA
# 4    2022-05-20  Canada
# ...

# %% [markdown]
# # Data Sorting

# %%
df.sort_values(by='Annual_Salary',ascending=False)
# Out:
#      EEID      Full_Name          Job_Title Department  Age  Annual_Salary  \
# 435   436    Vikas Mehta         Accountant         HR   57        1498893
# 467   468    Rohan Verma  Software Engineer      Sales   59        1498818
# 728   729    Rahul Gupta    Sales Executive      Sales   31        1497867
# 237   238    Rahul Verma  Software Engineer      Sales   38        1497323
# 796   797  Anjali Sharma  Software Engineer  Marketing   32        1496430
# ..    ...            ...                ...        ...  ...            ...
# 494   495    Pooja Patel       Data Analyst    Finance   38         303520
# 60     61   Anjali Gupta    Sales Executive  Marketing   27         302782
# 90     91    Rohan Gupta         Accountant  Marketing   36         301148
# 741   742    Pooja Verma         Accountant      Sales   41         300549
# 202   203    Vikas Kumar         Accountant  Marketing   30         300112
#
#       Hire_Date    Country
# 435  2016-04-09     Canada
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# Canada       227
# UK           212
# India        193
# Australia    187
# USA          181
# Name: count, dtype: int64

# %%
df.groupby('Department')['Annual_Salary'].max()
# Out:
# Department
# Finance      1495564
# HR           1498893
# IT           1495985
# Marketing    1496430
# Sales        1498818
# Name: Annual_Salary, dtype: int64
