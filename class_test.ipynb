# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#      EmpID          Name                        Email         Phone  \
# 0        1  Priya Sharma    priya.sharma1@company.com  919184935163
# 1        2   Vikas Verma     vikas.verma2@company.com  918536146025
# 2        3   Vikas Reddy     vikas.reddy3@company.com  916113971123
# 3        4  Arjun Sharma    arjun.sharma4@company.com  919259052811
# 4        5   Sneha Mehta     sneha.mehta5@company.com  916438989805
# ..     ...           ...                          ...           ...
# 995    996   Priya Kumar   priya.kumar996@company.com  917977795322
# 996    997   Arjun Mehta   arjun.mehta997@company.com  916597060483
# 997    998  Arjun Sharma  arjun.sharma998@company.com  919197432267
# 998    999   Rahul Gupta   rahul.gupta999@company.com  917320394595
# 999   1000   Priya Verma  priya.verma1000@company.com  916080772905
#
#     Department  Salary   Bonus  Experience_Years       City   Join_Date
# 0           IT  506787   68513                 4       Pune  2024-12-28
# ...

# %%
df=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\Data Anayltic\Pandas\employee_dataset_1000.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of      EmpID          Name                        Email         Phone  \
# 0        1  Priya Sharma    priya.sharma1@company.com  919184935163
# 1        2   Vikas Verma     vikas.verma2@company.com  918536146025
# 2        3   Vikas Reddy     vikas.reddy3@company.com  916113971123
# 3        4  Arjun Sharma    arjun.sharma4@company.com  919259052811
# 4        5   Sneha Mehta     sneha.mehta5@company.com  916438989805
# ..     ...           ...                          ...           ...
# 995    996   Priya Kumar   priya.kumar996@company.com  917977795322
# 996    997   Arjun Mehta   arjun.mehta997@company.com  916597060483
# 997    998  Arjun Sharma  arjun.sharma998@company.com  919197432267
# 998    999   Rahul Gupta   rahul.gupta999@company.com  917320394595
# 999   1000   Priya Verma  priya.verma1000@company.com  916080772905
#
#     Department  Salary   Bonus  Experience_Years       City   Join_Date
# ...

# %%
df.size
# Out:
# 10000

# %%
df.columns
# Out:
# Index(['EmpID', 'Name', 'Email', 'Phone', 'Department', 'Salary', 'Bonus',
#        'Experience_Years', 'City', 'Join_Date'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      EmpID          Name                        Email         Phone  \
# 0        1  Priya Sharma    priya.sharma1@company.com  919184935163
# 1        2   Vikas Verma     vikas.verma2@company.com  918536146025
# 2        3   Vikas Reddy     vikas.reddy3@company.com  916113971123
# 3        4  Arjun Sharma    arjun.sharma4@company.com  919259052811
# 4        5   Sneha Mehta     sneha.mehta5@company.com  916438989805
# ..     ...           ...                          ...           ...
# 995    996   Priya Kumar   priya.kumar996@company.com  917977795322
# 996    997   Arjun Mehta   arjun.mehta997@company.com  916597060483
# 997    998  Arjun Sharma  arjun.sharma998@company.com  919197432267
# 998    999   Rahul Gupta   rahul.gupta999@company.com  917320394595
# 999   1000   Priya Verma  priya.verma1000@company.com  916080772905
#
#     Department  Salary   Bonus  Experience_Years       City   Join_Date
# ...

# %%
# Data cleaning

# %%
# This row shows how many null values are in the dataset in the boolean form.
df.isnull()
# Out:
#      EmpID   Name  Email  Phone  Department  Salary  Bonus  Experience_Years  \
# 0    False  False  False  False       False   False  False             False
# 1    False  False  False  False       False   False  False             False
# 2    False  False  False  False       False   False  False             False
# 3    False  False  False  False       False   False  False             False
# 4    False  False  False  False       False   False  False             False
# ..     ...    ...    ...    ...         ...     ...    ...               ...
# 995  False  False  False  False       False   False  False             False
# 996  False  False  False  False       False   False  False             False
# 997  False  False  False  False       False   False  False             False
# 998  False  False  False  False       False   False  False             False
# 999  False  False  False  False       False   False  False             False
#
#       City  Join_Date
# ...

# %%
# This shows the null values in the columns 
df.isnull().sum()
# Out:
# EmpID               0
# Name                0
# Email               0
# Phone               0
# Department          0
# Salary              0
# Bonus               0
# Experience_Years    0
# City                0
# Join_Date           0
# dtype: int64

# %%
# This shows the null values in the entire dataset
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df['EmpID'].unique
# Out:
# <bound method Series.unique of 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: EmpID, Length: 1000, dtype: int64>

# %%
df['Department']
# Out:
# 0             IT
# 1          Sales
# 2      Marketing
# 3        Support
# 4             HR
#          ...
# 995           HR
# 996      Support
# 997      Support
# 998      Finance
# 999      Support
# Name: Department, Length: 1000, dtype: object

# %%
df['EmpID'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 995     996
# 996     997
# 997     998
# 998     999
# 999    1000
# Name: EmpID, Length: 1000, dtype: int64>

# %%
df['Department'].unique
# Out:
# <bound method Series.unique of 0             IT
# 1          Sales
# 2      Marketing
# 3        Support
# 4             HR
#          ...
# 995           HR
# 996      Support
# 997      Support
# 998      Finance
# 999      Support
# Name: Department, Length: 1000, dtype: object>

# %%
# This shows the how many duplicates values in the entire data
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
# This shows that drop the rows which entire row is duplicated
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
rq=df[(df['Join_Date']== '2018-03-07') & (df['City']== 'Mumbai')]

# %%
rq
# Out:
#      EmpID         Name                       Email         Phone Department  \
# 996    997  Arjun Mehta  arjun.mehta997@company.com  916597060483    Support
#
#      Salary   Bonus  Experience_Years    City   Join_Date
# 996  713405  147133                10  Mumbai  2018-03-07

# %%
rq1=df[(df['Join_Date']<= '2018-03-07') & (df['City']== 'Mumbai')]

# %%
rq1
# Out:
#      EmpID          Name                        Email         Phone  \
# 31      32   Vikas Yadav    vikas.yadav32@company.com  916602078388
# 53      54   Sneha Singh    sneha.singh54@company.com  919435488617
# 54      55    Neha Kumar     neha.kumar55@company.com  919445573666
# 55      56   Priya Kumar    priya.kumar56@company.com  919745927824
# 67      68   Pooja Mehta    pooja.mehta68@company.com  916401094954
# 71      72   Vikas Yadav    vikas.yadav72@company.com  916215686308
# 97      98   Pooja Patel    pooja.patel98@company.com  918387104291
# 102    103   Sneha Mehta   sneha.mehta103@company.com  916513483708
# 108    109   Rohit Yadav   rohit.yadav109@company.com  916318180503
# 165    166   Sneha Verma   sneha.verma166@company.com  919564040452
# 231    232  Anjali Reddy  anjali.reddy232@company.com  918302333490
# 235    236    Neha Patel    neha.patel236@company.com  919209700340
# 255    256   Rahul Mehta   rahul.mehta256@company.com  918185089287
# ...

# %%
# Data Cleaning
r = df[(df['Department'] == 'IT') & (df['Experience_Years'] >= 2)]

# %%
r
# Out:
#      EmpID          Name                        Email         Phone  \
# 0        1  Priya Sharma    priya.sharma1@company.com  919184935163
# 13      14   Rohit Yadav    rohit.yadav14@company.com  916613628803
# 21      22    Amit Verma     amit.verma22@company.com  919990448177
# 24      25   Vikas Gupta    vikas.gupta25@company.com  919062092518
# 37      38  Vikas Sharma   vikas.sharma38@company.com  919212530587
# ..     ...           ...                          ...           ...
# 952    953  Anjali Reddy  anjali.reddy953@company.com  916175553937
# 964    965   Arjun Gupta   arjun.gupta965@company.com  918079808343
# 969    970  Anjali Singh  anjali.singh970@company.com  917967269969
# 970    971   Arjun Yadav   arjun.yadav971@company.com  919848193865
# 977    978   Arjun Mehta   arjun.mehta978@company.com  917509058380
#
#     Department   Salary   Bonus  Experience_Years       City   Join_Date
# 0           IT   506787   68513                 4       Pune  2024-12-28
# ...

# %%
df['Salary'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      506787
# 1      283326
# 2      458496
# 3      417414
# 4      648382
#         ...
# 995    372227
# 996    713405
# 997    374357
# 998    470034
# 999    757778
# Name: Salary, Length: 1000, dtype: int64>

# %%
df['Salary'].mean()
# Out:
# np.float64(729210.213)

# %%
fr=df.groupby("Department")['Salary'].mean()

# %%
fr.min()
# Out:
# np.float64(673946.187919463)

# %%
fr
# Out:
# Department
# Finance       739098.346774
# HR            733401.380531
# IT            735961.035211
# Marketing     673946.187919
# Operations    739510.522989
# Sales         714359.561151
# Support       765989.955975
# Name: Salary, dtype: float64

# %%
fr1=df.groupby("City")['Salary'].mean()

# %%
fr1
# Out:
# City
# Bangalore    744706.861314
# Chennai      729214.037037
# Delhi        745030.237037
# Hyderabad    695892.720779
# Kolkata      711876.632353
# Mumbai       730576.526316
# Pune         749218.960265
# Name: Salary, dtype: float64

# %%
fr1.max()
# Out:
# np.float64(749218.9602649007)

# %%
fr2=df.groupby('Department')['Bonus'].median()

# %%
fr2
# Out:
# Department
# Finance       86072.0
# HR            76704.0
# IT            69413.0
# Marketing     86481.0
# Operations    75244.5
# Sales         85101.0
# Support       83327.0
# Name: Bonus, dtype: float64

# %%
fr2.max()
# Out:
# np.float64(86481.0)

# %%
fr2.min()
# Out:
# np.float64(69413.0)

# %%
# Bar Graph
plt.figure(figsize=(8,7))
plt.bar(fr1.index,fr1.values,color=['blue','green'],linewidth=2.1,edgecolor='black',label='Average Salary')
plt.title("City vs Salary")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.bar(fr.index,fr.values,color=['cyan','yellow'],linewidth=2.1,edgecolor='black',label='Average Salary in Department')
plt.title("Department vs Salary")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.bar(fr2.index,fr2.values,color=['brown','orange'],linewidth=2.1,edgecolor='black',label='Average Bonus')
plt.title("Department vs Bonus")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Line Graph

# %%
plt.figure(figsize=(8,9))
plt.plot(fr.index,fr.values,color='blue',linewidth=1.5,linestyle='--',marker='*',markerfacecolor='cyan',label='Average Salary in Department')
plt.plot(fr1.index,fr1.values,color='orange',linewidth=1.5,linestyle='--',marker='^',markerfacecolor='red',label='Average Salary in City')
plt.legend()
plt.title("This shows the average salary of city and department")
plt.grid()
plt.show()

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'])
df['Year'] = df['Join_Date'].dt.year

# %%
df['Year']
# Out:
# 0      2024
# 1      2023
# 2      2019
# 3      2024
# 4      2022
#        ...
# 995    2022
# 996    2018
# 997    2018
# 998    2018
# 999    2024
# Name: Year, Length: 1000, dtype: int32

# %%
sd=df.groupby("Join_Date")['Year'].mean()

# %%
sd
# Out:
# Join_Date
# 2016-02-29    2016.0
# 2016-03-02    2016.0
# 2016-03-08    2016.0
# 2016-03-12    2016.0
# 2016-03-13    2016.0
#                ...
# 2026-02-07    2026.0
# 2026-02-09    2026.0
# 2026-02-12    2026.0
# 2026-02-14    2026.0
# 2026-02-19    2026.0
# Name: Year, Length: 885, dtype: float64

# %%
fg=sd.max()

# %%
fg
# Out:
# np.float64(2026.0)

# %%
plt.figure(figsize=(8,6))
plt.plot(sd.index,sd.values,color='yellow',linestyle='--',linewidth=1.3,marker='o',markerfacecolor='green',label='Hiring based on the year')
plt.legend()
plt.grid()
plt.title("Hiring based on the year")
plt.show()
